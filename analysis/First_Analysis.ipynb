# %% [markdown]
# # This is my first attempt at creating a model using sklearn alogithms
# The algorithms I am most familiar with are Decision Trees and Random Forests, so that's where we'll start

# %%
# start with imports
import numpy as np
import pandas as pd
from pandas import DataFrame
import json
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /Users/mac28/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## Load the data from our JSON file.
# The data is stored as a dictionary of dictionaries in the json file. We store it that way beacause it's easy to add data to the existing master data file. Also, I haven't figured out how to get it in a database yet.

# %%
with open('/Users/mac28/CLCrawler/MasterApartmentData.json') as f:
    my_dict = json.load(f)
dframe = DataFrame(my_dict)

dframe = dframe.T
dframe
# Out:
#            bath  bed cat content        date dog  feet getphotos hasmap  \
# 5399866740    1    1   0     754  2016-01-12   0   750         8      0
# 5401772970    1    1   1    2632  2016-01-13   1   659         7      1
# 5402562933  1.5  NaN   0    1001  2016-01-14   0     1         2      1
# 5402607488    1    2   0    2259  2016-01-14   0   936        12      1
# 5402822514    1    1   0    1110  2016-01-14   0   624        16      1
# 5402918870  2.5    3   0    1318  2016-01-14   0  1684        22      1
# 5403011764    1    1   1    1649  2016-01-14   1   750        14      1
# 5403019783    1    1   1    1324  2016-01-14   1   640         5      1
# 5403242242    1    0   1    2862  2016-01-14   1   NaN        12      1
# 5403320258  1.5    3   0    1598  2016-01-14   0  1200        17      1
# 5404034182    2    2   1    4880  2016-01-15   1  1010        19      1
# 5404362542    1    2   1    1662  2016-01-15   1   850         8      1
# 5404431092    1    1   1    1877  2016-01-15   1   700        14      1
# 5404439790    1    2   1    1860  2016-01-15   1   900        14      1
# 5404442485    1    1   1    1435  2016-01-15   1   700        11      1
# 5404447075    1    2   1    2603  2016-01-15   1   850        24      1
# 5404478114    1    2   1    2375  2016-01-15   1   800        17      1
# 5404512932    1    2   1    2564  2016-01-15   1   850        23      1
# 5404543909    1    2   0    2626  2016-01-15   0   825        24      1
# 5404549721    1    1   0     722  2016-01-15   0   650         4      1
# 5404650486    1    2   0    3193  2016-01-15   0  1000        18      1
# 5404727169  1.5    3   0    2625  2016-01-15   0  1589        15      1
# 5404782936    1    2   0     879  2016-01-15   0   NaN        10      1
# 5404834100  NaN    0   0    1695  2016-01-15   0   NaN         2      0
# 5404855534    2    2   0    2465  2016-01-15   0   875         6      1
# 5404994129    1    2   0     699  2016-01-15   0   NaN         0      1
# 5404995096    1    2   0     678  2016-01-15   0   NaN         0      1
# 5405638400    1    1   1    2163  2016-01-16   1   298        16      1
# 5405717413  1.5    2   0    1088  2016-01-16   0  1172         8      1
# 5407108078    1    1   0    2319  2016-01-17   0   881        21      1
# ...         ...  ...  ..     ...         ...  ..   ...       ...    ...
# 5499137982    1    2   1    1544  2016-03-19   1   968         8      1
# 5499138633    1    1   0    2419  2016-03-19   1   800         9      1
# 5499139129    1    1   0    1777  2016-03-19   0   550         8      1
# 5499141339    1    0   0    1381  2016-03-19   0   340         7      1
# 5499145987    1    0   0    1381  2016-03-19   0   400         7      1
# 5499146335    1    1   0     772  2016-03-19   0   450         4      1
# 5499150151    1    1   1    2456  2016-03-19   1   505        14      1
# 5499151706    2    2   1    2515  2016-03-19   1   955        10      1
# 5499152039  1.5    2   0    2356  2016-03-19   0  1017         9      1
# 5499153859    2    2   1    1444  2016-03-19   1   950         9      0
# 5499154484    1    1   1    1251  2016-03-19   1   NaN         9      1
# 5499155508    2    2   1    1552  2016-03-19   1   970        19      1
# 5499159726    2    2   1    1978  2016-03-19   1   932         8      1
# 5499160450    1    0   1    1320  2016-03-19   1   NaN         6      1
# 5499161775    2    2   1    2278  2016-03-19   1   936         8      1
# 5499164874    1    0   1    1490  2016-03-19   1   440        16      1
# 5499165891    1    0   1    2492  2016-03-19   1   NaN        16      1
# 5499166373    1    1   1    1476  2016-03-19   1   NaN        10      1
# 5499167381  2.5    2   1    2299  2016-03-19   1  1249        21      1
# 5499167989    1    0   1    2106  2016-03-19   1   578        23      1
# 5499169838  2.5    3   1    2266  2016-03-19   1  1537        20      1
# 5499171887  2.5    3   1    2266  2016-03-19   1  1537        20      1
# 5499177030    2    3   1    2563  2016-03-19   1  1045        13      1
# 5499184093    1    1   1    1418  2016-03-19   1   647        24      1
# 5499189883    1    1   1    1561  2016-03-19   1   610        22      1
# 5499193325    1    1   1    2474  2016-03-19   1   640        12      1
# 5499195408    1    1   1    1695  2016-03-19   1   580         8      1
# 5499195916    1    1   1    1300  2016-03-19   1   842        17      1
# 5499196858    2    2   1    1285  2016-03-19   1  1053        10      1
# 5499207257    1    1   1    2951  2016-03-19   1   491        14      1
#
#            housingtype      lat             laundry     long  \
# 5399866740   apartment      NaN         w/d in unit      NaN
# 5401772970   apartment   45.531         w/d in unit -122.664
# 5402562933   apartment  45.5333     laundry on site -122.709
# 5402607488       condo  45.5328         w/d in unit -122.699
# 5402822514   apartment  45.5053         w/d in unit -122.618
# 5402918870   townhouse   45.602         w/d in unit -122.667
# 5403011764   apartment  45.5555         w/d hookups -122.658
# 5403019783   apartment  45.5198     laundry on site -122.687
# 5403242242   apartment  45.5413     laundry on site -122.676
# 5403320258       house  45.4079         w/d in unit -122.762
# 5404034182   apartment   45.464         w/d in unit -122.642
# 5404362542   apartment  45.5664     laundry on site -122.696
# 5404431092   apartment  45.5855         w/d in unit -122.732
# 5404439790   apartment  45.5855         w/d in unit -122.732
# 5404442485   apartment  45.5855         w/d in unit -122.732
# 5404447075   apartment  45.4784         w/d in unit -122.609
# 5404478114   apartment    45.61         w/d in unit  -122.73
# 5404512932   apartment  45.4784         w/d in unit -122.609
# 5404543909   apartment  45.4784         w/d in unit -122.609
# 5404549721   apartment  45.5627         w/d in unit  -122.64
# 5404650486   apartment  45.5353     laundry in bldg -122.643
# 5404727169       house   45.504         w/d in unit -122.649
# 5404782936      duplex  45.5193         w/d hookups   -122.6
# 5404834100   apartment      NaN                 NaN      NaN
# 5404855534   apartment  45.5218     laundry in bldg -122.686
# 5404994129   apartment  45.4941                 NaN -122.399
# 5404995096   apartment  45.4941                 NaN -122.399
# 5405638400   apartment  45.5413     laundry in bldg -122.676
# 5405717413   apartment  45.5318         w/d hookups -122.421
# 5407108078       condo  45.5314         w/d in unit -122.677
# ...                ...      ...                 ...      ...
# 5499137982   apartment  45.5332         w/d in unit -122.659
# 5499138633       condo   45.527         w/d in unit -122.685
# 5499139129   apartment  45.5104     laundry in bldg -122.682
# 5499141339   apartment  45.5177     laundry on site -122.686
# 5499145987   apartment  45.5177     laundry on site -122.686
# 5499146335   apartment  45.5142  no laundry on site -122.636
# 5499150151   apartment  45.5118         w/d in unit -122.645
# 5499151706   apartment   45.516         w/d in unit -122.685
# 5499152039   apartment  45.4849     laundry on site -122.634
# 5499153859   apartment      NaN         w/d in unit      NaN
# 5499154484   apartment  45.5272     laundry on site -122.688
# 5499155508   apartment  45.5742         w/d in unit -122.684
# 5499159726   apartment  45.5229         w/d in unit -122.639
# 5499160450   apartment  45.5272     laundry in bldg -122.688
# 5499161775   apartment  45.4983                 NaN -122.691
# 5499164874   apartment  45.5315         w/d in unit  -122.69
# 5499165891   apartment  45.5003         w/d in unit -122.672
# 5499166373   apartment  45.5328         w/d in unit -122.692
# 5499167381   townhouse  45.5037         w/d in unit -122.455
# 5499167989   apartment  45.5335         w/d in unit -122.695
# 5499169838   townhouse  45.5037         w/d in unit -122.455
# 5499171887   townhouse  45.5037         w/d in unit -122.455
# 5499177030   apartment    45.53         w/d in unit -122.683
# 5499184093   apartment   45.514         w/d in unit -122.678
# 5499189883   apartment   45.514         w/d in unit -122.678
# 5499193325   apartment  45.5118         w/d in unit -122.645
# 5499195408   apartment   45.513     laundry in bldg -122.685
# 5499195916   apartment  45.5505         w/d in unit -122.676
# 5499196858   apartment  45.5832         w/d in unit -122.684
# 5499207257   apartment  45.5333         w/d in unit -122.684
#
#                        parking price     smoking      time  \
# 5399866740  off-street parking  1400         NaN  12:22:07
# 5401772970     attached garage  1350  no smoking  16:24:11
# 5402562933             carport  1500  no smoking  09:12:40
# 5402607488     attached garage  1995         NaN  09:36:16
# 5402822514      street parking  1495         NaN  11:31:03
# 5402918870     attached garage  1800  no smoking  12:24:52
# 5403011764      street parking  1340         NaN  13:19:56
# 5403019783      street parking  1095  no smoking  13:24:43
# 5403242242      street parking  1235  no smoking  15:54:38
# 5403320258     attached garage  1725  no smoking  16:58:11
# 5404034182      street parking  1995  no smoking  08:57:41
# 5404362542  off-street parking  1395         NaN  11:53:28
# 5404431092  off-street parking  1195         NaN  12:32:22
# 5404439790  off-street parking  1395         NaN  12:37:14
# 5404442485  off-street parking  1195         NaN  12:38:46
# 5404447075      street parking  1395         NaN  12:41:25
# 5404478114  off-street parking  1295         NaN  12:59:13
# 5404512932  off-street parking  1395         NaN  13:19:34
# 5404543909  off-street parking  1395         NaN  13:37:48
# 5404549721      street parking  1150         NaN  13:41:21
# 5404650486     detached garage  1695  no smoking  14:44:29
# 5404727169  off-street parking  2795  no smoking  15:38:48
# 5404782936     attached garage  1450         NaN  16:22:51
# 5404834100                 NaN  1300         NaN  17:06:13
# 5404855534                 NaN  1695  no smoking  17:26:31
# 5404994129                 NaN  1100         NaN  19:56:47
# 5404995096                 NaN  1100         NaN  19:58:02
# 5405638400      street parking  1235  no smoking  10:05:11
# 5405717413     attached garage  1295  no smoking  10:48:07
# 5407108078     detached garage  2100  no smoking  11:46:56
# ...                        ...   ...         ...       ...
# 5499137982  off-street parking  1685  no smoking  16:31:14
# 5499138633     attached garage  2200         NaN  16:31:46
# 5499139129                 NaN  1050         NaN  16:32:11
# 5499141339      street parking   895  no smoking  16:33:59
# 5499145987      street parking   945  no smoking  16:38:01
# 5499146335      street parking   875         NaN  16:38:19
# 5499150151     attached garage  1390  no smoking  16:41:37
# 5499151706     attached garage  2359  no smoking  16:42:53
# 5499152039                 NaN  1420         NaN  16:43:11
# 5499153859                 NaN  1145         NaN  16:44:45
# 5499154484      street parking  1595  no smoking  16:45:20
# 5499155508             carport  2201  no smoking  16:46:16
# 5499159726     attached garage  2295         NaN  16:49:59
# 5499160450      street parking  1075  no smoking  16:50:38
# 5499161775                 NaN  2166         NaN  16:51:45
# 5499164874                 NaN  1325  no smoking  16:54:26
# 5499165891  off-street parking  1295  no smoking  16:55:21
# 5499166373     detached garage  1405  no smoking  16:55:45
# 5499167381     attached garage  1599  no smoking  16:56:38
# 5499167989     attached garage  1536  no smoking  16:57:12
# 5499169838     detached garage  1649  no smoking  16:58:47
# 5499171887     detached garage  1699  no smoking  17:00:39
# 5499177030     attached garage  3097  no smoking  17:05:05
# 5499184093     attached garage  1552  no smoking  17:11:21
# 5499189883     attached garage  1445  no smoking  17:16:24
# 5499193325     attached garage  1565  no smoking  17:19:31
# 5499195408     attached garage  1153  no smoking  17:21:26
# 5499195916     attached garage  1635  no smoking  17:21:53
# 5499196858                 NaN  1795  no smoking  17:22:47
# 5499207257     attached garage  1664  no smoking  17:32:23
#
#                        wheelchair
# 5399866740                    NaN
# 5401772970  wheelchair accessible
# 5402562933                    NaN
# 5402607488                    NaN
# 5402822514                    NaN
# 5402918870                    NaN
# 5403011764                    NaN
# 5403019783                    NaN
# 5403242242                    NaN
# 5403320258  wheelchair accessible
# 5404034182                    NaN
# 5404362542                    NaN
# 5404431092                    NaN
# 5404439790                    NaN
# 5404442485                    NaN
# 5404447075                    NaN
# 5404478114                    NaN
# 5404512932                    NaN
# 5404543909                    NaN
# 5404549721                    NaN
# 5404650486                    NaN
# 5404727169                    NaN
# 5404782936                    NaN
# 5404834100                    NaN
# 5404855534                    NaN
# 5404994129                    NaN
# 5404995096                    NaN
# 5405638400                    NaN
# 5405717413                    NaN
# 5407108078                    NaN
# ...                           ...
# 5499137982                    NaN
# 5499138633  wheelchair accessible
# 5499139129                    NaN
# 5499141339                    NaN
# 5499145987                    NaN
# 5499146335                    NaN
# 5499150151                    NaN
# 5499151706  wheelchair accessible
# 5499152039                    NaN
# 5499153859                    NaN
# 5499154484                    NaN
# 5499155508  wheelchair accessible
# 5499159726                    NaN
# 5499160450                    NaN
# 5499161775  wheelchair accessible
# 5499164874                    NaN
# 5499165891                    NaN
# 5499166373                    NaN
# 5499167381                    NaN
# 5499167989  wheelchair accessible
# 5499169838                    NaN
# 5499171887                    NaN
# 5499177030  wheelchair accessible
# 5499184093  wheelchair accessible
# 5499189883  wheelchair accessible
# 5499193325                    NaN
# 5499195408  wheelchair accessible
# 5499195916                    NaN
# 5499196858  wheelchair accessible
# 5499207257  wheelchair accessible
#
# [14455 rows x 18 columns]

# %% [markdown]
# ## Clean up the data a bit
# Right now the 'shared' and 'split' are included in number of bathrooms. If I were to conver that to a number I would consider a shared/split bathroom to be half or 0.5 of a bathroom.

# %%
dframe.bath = dframe.bath.replace('shared',0.5)
dframe.bath = dframe.bath.replace('split',0.5)

# %% [markdown]
# ## Get rid of null values
# I haven't figured out the best way to clean this up yet. For now I'm going to drop any rows that have a null value, though I recognize that this is not a good analysis practice. We ended up dropping 2,014 data points, which is a litle less than 16% of the data.
#
# 😬
#
# Also there were some CRAZY outliers, and this analysis is focused on finding a model for apartments for the 99% of us that can't afford crazy extravigant apartments

# %%
df = dframe[dframe.price < 10000][['bath','bed','feet','price']].dropna()
df
# Out:
#            bath bed  feet price
# 5399866740    1   1   750  1400
# 5401772970    1   1   659  1350
# 5402607488    1   2   936  1995
# 5402822514    1   1   624  1495
# 5402918870  2.5   3  1684  1800
# 5403011764    1   1   750  1340
# 5403019783    1   1   640  1095
# 5403320258  1.5   3  1200  1725
# 5404034182    2   2  1010  1995
# 5404362542    1   2   850  1395
# 5404431092    1   1   700  1195
# 5404439790    1   2   900  1395
# 5404442485    1   1   700  1195
# 5404447075    1   2   850  1395
# 5404478114    1   2   800  1295
# 5404512932    1   2   850  1395
# 5404543909    1   2   825  1395
# 5404549721    1   1   650  1150
# 5404650486    1   2  1000  1695
# 5404727169  1.5   3  1589  2795
# 5404855534    2   2   875  1695
# 5405638400    1   1   298  1235
# 5405717413  1.5   2  1172  1295
# 5407108078    1   1   881  2100
# 5408267602    2   2   890   995
# 5408650423    2   3  3000  2350
# 5408986289    1   0   349  1200
# 5409002928  2.5   4  2300  2750
# 5409038533    1   1   875  1395
# 5409045966    2   2  1133  2975
# ...         ...  ..   ...   ...
# 5499135395    1   1   748  1770
# 5499135755    1   1   763  1095
# 5499136900    1   2   870  1407
# 5499137516    1   1   670  1425
# 5499137982    1   2   968  1685
# 5499138633    1   1   800  2200
# 5499139129    1   1   550  1050
# 5499141339    1   0   340   895
# 5499145987    1   0   400   945
# 5499146335    1   1   450   875
# 5499150151    1   1   505  1390
# 5499151706    2   2   955  2359
# 5499152039  1.5   2  1017  1420
# 5499153859    2   2   950  1145
# 5499155508    2   2   970  2201
# 5499159726    2   2   932  2295
# 5499161775    2   2   936  2166
# 5499164874    1   0   440  1325
# 5499167381  2.5   2  1249  1599
# 5499167989    1   0   578  1536
# 5499169838  2.5   3  1537  1649
# 5499171887  2.5   3  1537  1699
# 5499177030    2   3  1045  3097
# 5499184093    1   1   647  1552
# 5499189883    1   1   610  1445
# 5499193325    1   1   640  1565
# 5499195408    1   1   580  1153
# 5499195916    1   1   842  1635
# 5499196858    2   2  1053  1795
# 5499207257    1   1   491  1664
#
# [12210 rows x 4 columns]

# %%
df.describe()
# Out:
#          bath    bed   feet  price
# count   12210  12210  12210  12210
# unique     11      7   1090   1350
# top         1      1    700    995
# freq     8085   4539    308    299

# %%
sns.distplot(df.price)

# %% [markdown]
# ## Let's simplify our data
# I have a hunch that bedrooms, bathrooms, and square footage have the greatest effect on housing price. Before we get too complicated, let's see how accurate we can be with just a simple set of data

# %%
features = df[['bath','bed','feet']].values
price = df[['price']].values

# %% [markdown]
# ### Split data into Training and Testing Data

# %%
from sklearn.cross_validation import train_test_split
features_train, features_test, price_train, price_test = train_test_split(features, price, test_size=0.1, random_state=42)

# %%
from sklearn import tree
from sklearn.metrics import r2_score

# %%
clf = tree.DecisionTreeRegressor()
clf = clf.fit(features_train, price_train)

# %%
pred = clf.predict(features_test)
pred = np.array([[item] for item in pred])
print pred
print price_test
# Out:
# [[  995.8452381 ]
#  [ 1308.14      ]
#  [ 1995.        ]
#  ...,
#  [ 1817.87878788]
#  [ 1396.54761905]
#  [ 2339.25      ]]
# [[965]
#  [1880]
#  [1995]
#  ...,
#  [1751]
#  [1450]
#  [2439]]

# %%
r2_score(pred, price_test)
# Out:
# 0.66314278725193798

# %% [markdown]
# ## 72% Woot!
# Wait, is that even good? I think that for the most part, it's pretty bad, but for our first run through, with super simple data, I'm willing to go with it.
# ## What does it look like?

# %%
plt.scatter(pred,price_test)

# %% [markdown]
# Ok, so we can see that there's at least a relationship, which we already knew from the R^2 score.Visually it looks like there is more variation in the prices, and that we're better at predicting on the higher end, but it could very well be that we just have WAY more data on the lower end. Remember our plot from before? We see a similar thing going on

# %%
sns.distplot(df.price)

# %% [markdown]
# ## Ok, so we tried decision trees. Let's try decision trees on steroids. Random Forest!

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor()
reg = reg.fit(features_train, price_train)
# Out:
# /Users/mac28/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()

# %%
forest_pred = reg.predict(features_test)
forest_pred = np.array([[item] for item in forest_pred])

# %%
r2_score(forest_pred, price_test)
# Out:
# 0.67041595546408894

# %% [markdown]
# #### hmmm, it's not actually that much higher of accuracy? Maybe overfitting the data? Maybe Not enough features? Since the dataset is relatively small let's try to up the number of "Trees" that we use. We'll up it from the default 10 to 100

# %%
reg = RandomForestRegressor(n_estimators = 100)
reg = reg.fit(features_train, price_train)
# Out:
# /Users/mac28/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app

# %%
forest_pred = reg.predict(features_test)
forest_pred = np.array([[item] for item in forest_pred])

# %%
r2_score(forest_pred, price_test)
# Out:
# 0.67658076791856303

# %% [markdown]
# ##### Still no difference, ok, I can take a hint. Let's look into over-fitting

# %%
reg = RandomForestRegressor(min_samples_split = 20)
reg = reg.fit(features_train, price_train)
# Out:
# /Users/mac28/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app

# %%
forest_pred = reg.predict(features_test)
forest_pred = np.array([[item] for item in forest_pred])

# %%
r2_score(forest_pred, price_test)
# Out:
# 0.58103431167805031

# %% [markdown]
# Shoot, we got worse. Feel free to play with it, we get better at predicting as the min samples split goes down.

# %% [markdown]
# # Let's try a more complicated set of data

# %%
df2 = dframe[dframe.price < 10000][['bath','bed','feet','dog','cat','content','getphotos', 'hasmap', 'price',]].dropna()
df2
# Out:
#            bath bed  feet dog cat content getphotos hasmap price
# 5399866740    1   1   750   0   0     754         8      0  1400
# 5401772970    1   1   659   1   1    2632         7      1  1350
# 5402607488    1   2   936   0   0    2259        12      1  1995
# 5402822514    1   1   624   0   0    1110        16      1  1495
# 5402918870  2.5   3  1684   0   0    1318        22      1  1800
# 5403011764    1   1   750   1   1    1649        14      1  1340
# 5403019783    1   1   640   1   1    1324         5      1  1095
# 5403320258  1.5   3  1200   0   0    1598        17      1  1725
# 5404034182    2   2  1010   1   1    4880        19      1  1995
# 5404362542    1   2   850   1   1    1662         8      1  1395
# 5404431092    1   1   700   1   1    1877        14      1  1195
# 5404439790    1   2   900   1   1    1860        14      1  1395
# 5404442485    1   1   700   1   1    1435        11      1  1195
# 5404447075    1   2   850   1   1    2603        24      1  1395
# 5404478114    1   2   800   1   1    2375        17      1  1295
# 5404512932    1   2   850   1   1    2564        23      1  1395
# 5404543909    1   2   825   0   0    2626        24      1  1395
# 5404549721    1   1   650   0   0     722         4      1  1150
# 5404650486    1   2  1000   0   0    3193        18      1  1695
# 5404727169  1.5   3  1589   0   0    2625        15      1  2795
# 5404855534    2   2   875   0   0    2465         6      1  1695
# 5405638400    1   1   298   1   1    2163        16      1  1235
# 5405717413  1.5   2  1172   0   0    1088         8      1  1295
# 5407108078    1   1   881   0   0    2319        21      1  2100
# 5408267602    2   2   890   0   0     992         0      1   995
# 5408650423    2   3  3000   0   0    1008        16      1  2350
# 5408986289    1   0   349   0   0     704        15      1  1200
# 5409002928  2.5   4  2300   0   0    1531        16      1  2750
# 5409038533    1   1   875   0   0    1741        17      1  1395
# 5409045966    2   2  1133   1   1    1750         0      1  2975
# ...         ...  ..   ...  ..  ..     ...       ...    ...   ...
# 5499135395    1   1   748   1   1    3184        16      1  1770
# 5499135755    1   1   763   0   0    1478         8      1  1095
# 5499136900    1   2   870   1   1    3328         0      1  1407
# 5499137516    1   1   670   1   1    2762        15      1  1425
# 5499137982    1   2   968   1   1    1544         8      1  1685
# 5499138633    1   1   800   1   0    2419         9      1  2200
# 5499139129    1   1   550   0   0    1777         8      1  1050
# 5499141339    1   0   340   0   0    1381         7      1   895
# 5499145987    1   0   400   0   0    1381         7      1   945
# 5499146335    1   1   450   0   0     772         4      1   875
# 5499150151    1   1   505   1   1    2456        14      1  1390
# 5499151706    2   2   955   1   1    2515        10      1  2359
# 5499152039  1.5   2  1017   0   0    2356         9      1  1420
# 5499153859    2   2   950   1   1    1444         9      0  1145
# 5499155508    2   2   970   1   1    1552        19      1  2201
# 5499159726    2   2   932   1   1    1978         8      1  2295
# 5499161775    2   2   936   1   1    2278         8      1  2166
# 5499164874    1   0   440   1   1    1490        16      1  1325
# 5499167381  2.5   2  1249   1   1    2299        21      1  1599
# 5499167989    1   0   578   1   1    2106        23      1  1536
# 5499169838  2.5   3  1537   1   1    2266        20      1  1649
# 5499171887  2.5   3  1537   1   1    2266        20      1  1699
# 5499177030    2   3  1045   1   1    2563        13      1  3097
# 5499184093    1   1   647   1   1    1418        24      1  1552
# 5499189883    1   1   610   1   1    1561        22      1  1445
# 5499193325    1   1   640   1   1    2474        12      1  1565
# 5499195408    1   1   580   1   1    1695         8      1  1153
# 5499195916    1   1   842   1   1    1300        17      1  1635
# 5499196858    2   2  1053   1   1    1285        10      1  1795
# 5499207257    1   1   491   1   1    2951        14      1  1664
#
# [12210 rows x 9 columns]

# %%
features = df2[['bath','bed','feet','dog','cat','content','getphotos', 'hasmap']].values
price = df2[['price']].values

# %%
features_train, features_test, price_train, price_test = train_test_split(features, price, test_size=0.1, random_state=42)

# %%
clf = tree.DecisionTreeRegressor()
clf = clf.fit(features_train, price_train)

# %%
pred = clf.predict(features_test)
pred = np.array([[item] for item in pred])

# %%
r2_score(pred, price_test)
# Out:
# 0.66876661699345319

# %% [markdown]
# Ahhhhh! We're just getting worse!

# %%
plt.scatter(pred,price_test)

# %% [markdown]
# Let's try

# %%
reg = RandomForestRegressor(n_estimators=50)
reg = reg.fit(features_train, price_train)
forest_pred = reg.predict(features_test)
forest_pred = np.array([[item] for item in forest_pred])
r2_score(forest_pred, price_test)
# Out:
# /Users/mac28/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# 0.77622254289033721

# %%
plt.scatter(forest_pred, price_test)

# %% [markdown]
# Woo! Broke 80%!!! Well, now we've reached my limit. I'm not really sure how to progress from here. Will return after learning a bit more!
#
# Note #1 to Riley: Next time look into another regressor? see if there's one that's inherantly better at this kind of thing.
#
# Note #2 to Riley: Find a regressor that can take as inputs both continuous and discrete features, today we only worked with continuous
#
# Note #3 to Riley: Clearly geography has a huge impact on housing prices. (ie. Downtown is way more expensive than the boonies.) Figure out the best way to model the effect that geography has, and then make that "multiplier" a feature in your model?
